# %% [markdown]
# <a href="https://colab.research.google.com/github/shalabh147/Brain-Tumor-Segmentation-and-Survival-Prediction-using-Deep-Neural-Networks/blob/master/2daxis1_4class_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
import tensorflow as tf
import keras
import keras.backend as K
from keras.utils import to_categorical
from keras import metrics
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout,Maximum
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D,MaxPooling3D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from sklearn.utils import class_weight


from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping

import os
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
# from medpy.io import load
import numpy as np

#import cv2
import nibabel as nib
from PIL import Image

# %%
def conv_block(input_mat,num_filters,kernel_size,batch_norm):
  X = Conv2D(num_filters,kernel_size=(kernel_size,kernel_size),strides=(1,1),padding='same')(input_mat)
  if batch_norm:
    X = BatchNormalization()(X)
 
  X = Activation('relu')(X)

  X = Conv2D(num_filters,kernel_size=(kernel_size,kernel_size),strides=(1,1),padding='same')(X)
  if batch_norm:
    X = BatchNormalization()(X)
 
  X = Activation('relu')(X)
 
  return X

def Unet_with_slice(input_img, n_filters = 16 , dropout = 0.3 , batch_norm = True):
  c1 = Conv2D(16,kernel_size = (1,6) , strides = (1,1) ,padding = 'valid')(input_img)
  if batch_norm:
    c1 = BatchNormalization()(c1)
  #print(c1.shape)
  c1 = Activation('relu')(c1)

  c1 = Conv2D(n_filters,kernel_size=(3,3),strides=(1,1),padding='same')(c1)
  if batch_norm:
    c1 = BatchNormalization()(c1)
 
  c1 = Activation('relu')(c1)

  p1 = MaxPooling2D(pool_size = (2,2) , strides = 2)(c1)
  p1 = Dropout(dropout)(p1)

  #print(p1.shape)
  c2 = conv_block(p1 , n_filters*2,3,batch_norm)
  p2 = MaxPooling2D(pool_size=(3,3), strides=3)(c2)
  p2 = Dropout(dropout)(p2)
  #print(p2.shape)

  c3 = conv_block(p2, n_filters*4,3,batch_norm)
  #print(c3.shape)
  p3 = MaxPooling2D(pool_size = (2,1) , strides = (2,1))(c3)
  p3 = Dropout(dropout)(p3)
  #print(p3.shape)

  c4 = conv_block(p3, n_filters*8,3,batch_norm)
  p4 = MaxPooling2D(pool_size = (4,4) , strides = (4,5))(c4)
  p4 = Dropout(dropout)(p4)

  c5 = conv_block(p4,n_filters*16,3,batch_norm)

  u6 = Conv2DTranspose(n_filters*8,kernel_size = (4,4) , strides = (4,5) , padding = 'same')(c5)
  u6 = concatenate([u6,c4])
  c6 = conv_block(u6,n_filters*8,3,batch_norm)
  c6 = Dropout(dropout)(c6)

  u7 = Conv2DTranspose(n_filters*4,kernel_size = (3,3) , strides = (2,1) , padding = 'same')(c6)
  u7 = concatenate([u7,c3])
  c7 = conv_block(u7,n_filters*4,3,batch_norm)
  c7 = Dropout(dropout)(c7)

  u8 = Conv2DTranspose(n_filters*2,kernel_size = (3,3) , strides = (3,3) , padding = 'same')(c7)
  u8 = concatenate([u8,c2])
  c8 = conv_block(u8,n_filters*2,3,batch_norm)
  c8 = Dropout(dropout)(c8)

  u9 = Conv2DTranspose(n_filters,kernel_size = (3,3) , strides = (2,2) , padding = 'same')(c8)
  u9 = concatenate([u9,c1])
  c9 = conv_block(u9,n_filters,3,batch_norm)
  c9 = Dropout(dropout)(c9)

  c10 = Conv2DTranspose(n_filters, kernel_size = (1,6) , strides = (1,1), padding = 'valid')(c9)

  outputs = Conv2D(4, kernel_size = (1,1), activation = 'softmax')(c10)

  model = Model(inputs = input_img , outputs = outputs)

  return model

# %%
def standardize(image):

  standardized_image = np.zeros(image.shape)

  #
 
      # iterate over the `z` dimension
  for z in range(image.shape[2]):
      # get a slice of the image
      # at channel c and z-th dimension `z`
      image_slice = image[:,:,z]

      # subtract the mean from image_slice
      centered = image_slice - np.mean(image_slice)
     
      # divide by the standard deviation (only if it is different from zero)
      if(np.std(centered)!=0):
          centered = centered/np.std(centered)

      # update  the slice of standardized image
      # with the scaled centered and scaled image
      standardized_image[:, :, z] = centered

  ### END CODE HERE ###

  return standardized_image


def dice_coef(y_true, y_pred, epsilon=0.00001):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
   
    """
    axis = (0,1,2)
    dice_numerator = 2. * K.sum(y_true * y_pred, axis=axis) + epsilon
    dice_denominator = K.sum(y_true*y_true, axis=axis) + K.sum(y_pred*y_pred, axis=axis) + epsilon
    return K.mean((dice_numerator)/(dice_denominator))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
input_img = Input((240,155,4))
model = Unet_with_slice(input_img,32,0.15,True)
learning_rate = 0.00095
#epochs = 5000
decay_rate = 0.0000002
model.compile(optimizer=Adam(lr=learning_rate, decay = decay_rate), loss=dice_coef_loss, metrics=[dice_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 240, 155, 4) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 240, 150, 16) 400         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 240, 150, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 240, 150, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 150, 32) 4640        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 150, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 150, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 120, 75, 32)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 120, 75, 32)  0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 120, 75, 64)  18496       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 120, 75, 64)  256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 120, 75, 64)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 75, 64)  36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 75, 64)  256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 120, 75, 64)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 40, 25, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 40, 25, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 25, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 25, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 40, 25, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 25, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 40, 25, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 40, 25, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 25, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 20, 25, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 20, 25, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 20, 25, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 20, 25, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 25, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 25, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 20, 25, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 5, 256)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 5, 5, 256)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 5, 5, 512)    1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 5, 5, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5, 5, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 5, 5, 512)    2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 5, 5, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 5, 5, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 20, 25, 256)  2097408     activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 20, 25, 512)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 25, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 20, 25, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 20, 25, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 20, 25, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 20, 25, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 20, 25, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 20, 25, 256)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 40, 25, 128)  295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 40, 25, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 40, 25, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 40, 25, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 40, 25, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 40, 25, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 40, 25, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 40, 25, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 40, 25, 128)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 120, 75, 64)  73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120, 75, 128) 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 75, 64)  73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 75, 64)  256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 120, 75, 64)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 75, 64)  36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 120, 75, 64)  256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 120, 75, 64)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 120, 75, 64)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 240, 150, 32) 18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 150, 64) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 240, 150, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 150, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 240, 150, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 150, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 240, 150, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 240, 150, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 240, 150, 32) 0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 240, 155, 32) 6176        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 155, 4)  132         conv2d_transpose_4[0][0]
# ==================================================================================================
# Total params: 9,560,884
# Trainable params: 9,555,028
# Non-trainable params: 5,856
# __________________________________________________________________________________________________

# %%
path = '/home/vivek/Desktop/BTP_2020/Segmentation/dataset/MICCAI_BraTS_2018_Data_Training/HGG'
all_images = os.listdir(path)
#print(len(all_images))
all_images.sort()
data = np.zeros((240,240,155,4))
image_data2=np.zeros((240,240,155))
loss_hist = []
accu_hist = []
epoch_wise_loss = []
epoch_wise_accu = []
for epochs in range(45):
  epoch_loss = 0
  epoch_accu = 0
  for image_num in range(180):
    x_to = []
    y_to = []
    print(epochs)
    print(image_num)

# data preprocessing starts here

    x = all_images[image_num]
    print(x)
    folder_path = path + '/' + x;
    modalities = os.listdir(folder_path)
    modalities.sort()
    #data = []
    w = 0
    for j in range(len(modalities)):
      #print(modalities[j])
     
      image_path = folder_path + '/' + modalities[j]
      if not(image_path.find('seg.nii') == -1):
        img = nib.load(image_path);
        image_data2 = img.get_data()
        image_data2 = np.asarray(image_data2)
        print("Entered ground truth")
      else:
        img = nib.load(image_path);
        image_data = img.get_data()
        image_data = np.asarray(image_data)
        image_data = standardize(image_data)
        data[:,:,:,w] = image_data
        print("Entered modality")
        w = w+1
     
    print(data.shape)
    print(image_data2.shape)  
   
    '''
    reshaped_data=data[56:184,75:203,13:141,:]
    reshaped_data=reshaped_data.reshape(1,128,128,128,4)
    reshaped_image_data2=image_data2[56:184,75:203,13:141]

       
    reshaped_image_data2=reshaped_image_data2.reshape(1,128,128,128)
    reshaped_image_data2[reshaped_image_data2==4] = 3
    hello = reshaped_image_data2.flatten()
    #y_to = keras.utils.to_categorical(y_to,num_classes=2)
    print(reshaped_image_data2.shape)
    #print(hello[hello==3].shape)
    print("Number of classes",np.unique(hello))
    class_weights = class_weight.compute_class_weight('balanced',np.unique(hello),hello)
    print(class_weights)
   
   
    '''
   
   
    for slice_no in range(0,240):
        a = slice_no
        X = data[slice_no,:,:,:]

        Y = image_data2[slice_no,:,:]
        # imgplot = plt.imshow(X[:,:,2])
        # plt.show(block=False)
        # plt.pause(0.3)
        # plt.close()

        # imgplot = plt.imshow(Y)
        # plt.show(block=False)
        # plt.pause(0.3)
        # plt.close()

        if(X.any()!=0 and Y.any()!=0 and len(np.unique(Y)) == 4):
          #print(slice_no)
          x_to.append(X)
          y_to.append(Y)
          if len(y_to)>=50:
                break;

        #reshaped_image_data2 = to_categorical(reshaped_image_data2, num_classes = 4)

        #print(reshaped_data.shape)
        #print(reshaped_image_data2.shape)
        #print(type(reshaped_data))

    x_to = np.asarray(x_to)
    y_to = np.asarray(y_to)
    print(x_to.shape)
    print(y_to.shape)

 
    y_to[y_to==4] = 3        
    #y_to = one_hot_encode(y_to)
    #y_to[y_to==2] = 1
    #y_to[y_to==1] = 1
    #y_to[y_to==0] = 0
    print(y_to.shape)
   
   
    from sklearn.utils import shuffle
    x_to,y_to = shuffle(x_to,y_to)
   
    hello = y_to.flatten()
    #print(hello[hello==3].shape)
    print("Number of classes",np.unique(hello))
    class_weights = class_weight.compute_class_weight('balanced',np.unique(hello),hello)
    class_weights = {i : class_weights[i] for i in range(4)}
 
    #class_weights.insert(3,0)
    print("class_weights",class_weights)


    y_to = keras.utils.to_categorical(y_to,num_classes=4)
    history = model.fit(x=x_to,y=y_to, epochs = 1 , batch_size = 50)
    print(history.history['loss'])
    epoch_loss += history.history['loss'][0]
    epoch_accu += history.history['dice_coef'][0]
   
    loss_hist.append(history.history['loss'])
    accu_hist.append(history.history['dice_coef'])
 
  model.save('../working/2d_4class_axis1.h5')
  epoch_loss = epoch_loss/180
  epoch_accu = epoch_accu/180

  epoch_wise_loss.append(epoch_loss)
  epoch_wise_accu.append(epoch_accu)
 
  plt.plot(epoch_wise_loss)
  plt.title('Model_loss vs epochs')
  plt.ylabel('Loss')
  plt.xlabel('epochs')
  s = '../working/epochwise_loss_' + str(epochs)
  plt.savefig(s)
  plt.show()
  plt.close()
 
  plt.plot(epoch_wise_accu)
  plt.title('Model_Accuracy vs epochs')
  plt.ylabel('Accuracy')
  plt.xlabel('epochs')
  s = '../working/epochwise_accu_' + str(epochs)
  plt.savefig(s)
  plt.show()
  plt.close()
   
  plt.plot(accu_hist)
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  s = '../working/accuracy_plot_' + str(epochs)
  plt.savefig(s)
  plt.show()
  plt.close()
   
  plt.plot(loss_hist)
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  s = '../working/loss_plot_' + str(epochs)
  plt.savefig(s)
  plt.show()
  plt.close()

model.save('../working/2d_4class_axis1.h5')
# Out:
# 0
# 0
# Brats18_2013_10_1
# <ipython-input-8-13145fed0c36>:40: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   image_data = img.get_data()
# Entered modality
# Entered ground truth
# <ipython-input-8-13145fed0c36>:35: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   image_data2 = img.get_data()
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (43, 240, 155, 4)
# (43, 240, 155)
# (43, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.268034341104028, 1: 14.708154032880945, 2: 8.169060118889547, 3: 12.701286326822297}
# 1/1 [==============================] - 33s 33s/step - loss: 0.7939 - dice_coef: 0.2061
# [0.7938987612724304]
# 0
# 1
# Brats18_2013_11_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2695764692787177, 1: 10.24996693559053, 2: 6.61526204973539, 3: 23.95178736993922}
# 1/1 [==============================] - 73s 73s/step - loss: 0.7485 - dice_coef: 0.2515
# [0.7484933733940125]
# 0
# 2
# Brats18_2013_12_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2771151183877502, 1: 13.596888797918067, 2: 4.410049221839702, 3: 10.978114597351087}
# 1/1 [==============================] - 37s 37s/step - loss: 0.6441 - dice_coef: 0.3559
# [0.6441423892974854]
# 0
# 3
# Brats18_2013_13_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (18, 240, 155, 4)
# (18, 240, 155)
# (18, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25554520890897153, 1: 405.3268765133172, 2: 17.07814731687411, 3: 38.794901506373115}
# 1/1 [==============================] - 11s 11s/step - loss: 0.7292 - dice_coef: 0.2708
# [0.7292479276657104]
# 0
# 4
# Brats18_2013_14_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2765425872610806, 1: 22.021216139420346, 2: 3.8442460317460316, 3: 12.758251707959502}
# 1/1 [==============================] - 26s 26s/step - loss: 0.5490 - dice_coef: 0.4510
# [0.5489784479141235]
# 0
# 5
# Brats18_2013_17_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2679707525771295, 1: 42.61754193016222, 2: 8.33826456506536, 3: 8.009232147163182}
# 1/1 [==============================] - 30s 30s/step - loss: 0.4997 - dice_coef: 0.5003
# [0.4996718168258667]
# 0
# 6
# Brats18_2013_18_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (48, 240, 155, 4)
# (48, 240, 155)
# (48, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.27087082786717137, 1: 101.13275940190303, 2: 3.988634535999571, 3: 21.007058823529412}
# 1/1 [==============================] - 28s 28s/step - loss: 0.4648 - dice_coef: 0.5352
# [0.4648211896419525]
# 0
# 7
# Brats18_2013_19_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (46, 240, 155, 4)
# (46, 240, 155)
# (46, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2613304272184375, 1: 15.90216340792506, 2: 14.675311310075125, 3: 23.584541595457303}
# 1/1 [==============================] - 24s 24s/step - loss: 0.5587 - dice_coef: 0.4413
# [0.5586743950843811]
# 0
# 8
# Brats18_2013_20_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (49, 240, 155, 4)
# (49, 240, 155)
# (49, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2791639661009058, 1: 7.805755395683454, 2: 5.139454362953523, 3: 10.505083104728094}
# 1/1 [==============================] - 27s 27s/step - loss: 0.4107 - dice_coef: 0.5893
# [0.4106769561767578]
# 0
# 9
# Brats18_2013_21_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (47, 240, 155, 4)
# (47, 240, 155)
# (47, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26700304203877684, 1: 8.28295844308427, 2: 10.725590754054917, 3: 24.534126627750336}
# 1/1 [==============================] - 24s 24s/step - loss: 0.5175 - dice_coef: 0.4825
# [0.5175169706344604]
# 0
# 10
# Brats18_2013_22_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.28212441504687813, 1: 10.979669901537154, 2: 4.290380321455593, 3: 7.615709653116709}
# 1/1 [==============================] - 30s 30s/step - loss: 0.3723 - dice_coef: 0.6277
# [0.3722769021987915]
# 0
# 11
# Brats18_2013_23_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26911295162506604, 1: 9.562982005141388, 2: 21.497919556171983, 3: 7.518675419590596}
# 1/1 [==============================] - 40s 40s/step - loss: 0.4184 - dice_coef: 0.5816
# [0.4184386730194092]
# 0
# 12
# Brats18_2013_25_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (21, 240, 155, 4)
# (21, 240, 155)
# (21, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2560710338163238, 1: 23.7417943107221, 2: 20.371336184416396, 3: 275.8474576271187}
# 1/1 [==============================] - 12s 12s/step - loss: 0.6370 - dice_coef: 0.3630
# [0.6370217800140381]
# 0
# 13
# Brats18_2013_26_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (18, 240, 155, 4)
# (18, 240, 155)
# (18, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.253928766458346, 1: 547.0588235294117, 2: 30.942698706099815, 3: 36.04651162790697}
# 1/1 [==============================] - 10s 10s/step - loss: 0.5083 - dice_coef: 0.4917
# [0.5083205103874207]
# 0
# 14
# Brats18_2013_27_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (42, 240, 155, 4)
# (42, 240, 155)
# (42, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26325544404979345, 1: 33.30775134305449, 2: 8.395486297689414, 3: 19.130179253599763}
# 1/1 [==============================] - 21s 21s/step - loss: 0.3354 - dice_coef: 0.6646
# [0.335395872592926]
# 0
# 15
# Brats18_2013_3_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (40, 240, 155, 4)
# (40, 240, 155)
# (40, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2651079459692902, 1: 35.66634707574305, 2: 7.245388855345422, 3: 16.156351791530945}
# 1/1 [==============================] - 20s 20s/step - loss: 0.5338 - dice_coef: 0.4662
# [0.5338062047958374]
# 0
# 16
# Brats18_2013_4_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26683943324452075, 1: 37.4577090381827, 2: 5.207050234037312, 3: 29.687799272170082}
# 1/1 [==============================] - 27s 27s/step - loss: 0.5733 - dice_coef: 0.4267
# [0.5732502341270447]
# 0
# 17
# Brats18_2013_5_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (32, 240, 155, 4)
# (32, 240, 155)
# (32, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26229924324553006, 1: 269.0777576853526, 2: 6.400963585916159, 3: 36.20878452366468}
# 1/1 [==============================] - 16s 16s/step - loss: 0.3689 - dice_coef: 0.6311
# [0.3689407706260681]
# 0
# 18
# Brats18_2013_7_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (39, 240, 155, 4)
# (39, 240, 155)
# (39, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2735731504584443, 1: 17.927932380999458, 2: 4.619381789930843, 3: 13.809777642400244}
# 1/1 [==============================] - 20s 20s/step - loss: 0.3002 - dice_coef: 0.6998
# [0.30021148920059204]
# 0
# 19
# Brats18_CBICA_AAB_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.27587237965734873, 1: 30.110729780483066, 2: 3.532548828941071, 3: 16.99437175645055}
# 1/1 [==============================] - 27s 27s/step - loss: 0.2742 - dice_coef: 0.7258
# [0.2742496728897095]
# 0
# 20
# Brats18_CBICA_AAG_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (26, 240, 155, 4)
# (26, 240, 155)
# (26, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2623085977121223, 1: 26.397379912663755, 2: 8.07966050723427, 3: 38.39314067958082}
# 1/1 [==============================] - 13s 13s/step - loss: 0.3239 - dice_coef: 0.6761
# [0.323938250541687]
# 0
# 21
# Brats18_CBICA_AAL_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (16, 240, 155, 4)
# (16, 240, 155)
# (16, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25319471149755823, 1: 203.00136425648023, 2: 37.1072319201995, 3: 53.776653415251175}
# 1/1 [==============================] - 8s 8s/step - loss: 0.5006 - dice_coef: 0.4994
# [0.5005599856376648]
# 0
# 22
# Brats18_CBICA_AAP_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (31, 240, 155, 4)
# (31, 240, 155)
# (31, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26572555149803584, 1: 26.444689047881123, 2: 6.8867496357165034, 3: 18.622827982688456}
# 1/1 [==============================] - 16s 16s/step - loss: 0.2156 - dice_coef: 0.7844
# [0.21558088064193726]
# 0
# 23
# Brats18_CBICA_ABB_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (43, 240, 155, 4)
# (43, 240, 155)
# (43, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2530634664695653, 1: 110.3476821192053, 2: 77.09658762290341, 3: 37.894437600682274}
# 1/1 [==============================] - 22s 22s/step - loss: 0.5978 - dice_coef: 0.4022
# [0.5978373289108276]
# 0
# 24
# Brats18_CBICA_ABE_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (34, 240, 155, 4)
# (34, 240, 155)
# (34, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.27556348025694855, 1: 15.947949765471327, 2: 4.3526739624199875, 3: 12.718716061300833}
# 1/1 [==============================] - 18s 18s/step - loss: 0.3803 - dice_coef: 0.6197
# [0.3803062438964844]
# 0
# 25
# Brats18_CBICA_ABM_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (24, 240, 155, 4)
# (24, 240, 155)
# (24, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2591314221229969, 1: 65.68569746909947, 2: 10.06629684751725, 3: 37.89473684210526}
# 1/1 [==============================] - 13s 13s/step - loss: 0.3172 - dice_coef: 0.6828
# [0.31716036796569824]
# 0
# 26
# Brats18_CBICA_ABN_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (13, 240, 155, 4)
# (13, 240, 155)
# (13, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2602300097505537, 1: 770.0636942675159, 2: 6.7860350246969015, 3: 116.47398843930635}
# 1/1 [==============================] - 6s 6s/step - loss: 0.3618 - dice_coef: 0.6382
# [0.3618198037147522]
# 0
# 27
# Brats18_CBICA_ABO_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2755687828571327, 1: 18.388168301170516, 2: 4.793863854266539, 3: 9.245635662305643}
# 1/1 [==============================] - 149s 149s/step - loss: 0.4050 - dice_coef: 0.5950
# [0.40495291352272034]
# 0
# 28
# Brats18_CBICA_ABY_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (22, 240, 155, 4)
# (22, 240, 155)
# (22, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2608486121859394, 1: 392.7063339731286, 2: 7.5367443916454855, 3: 32.12435233160622}
# 1/1 [==============================] - 14s 14s/step - loss: 0.3804 - dice_coef: 0.6196
# [0.38043883442878723]
# 0
# 29
# Brats18_CBICA_ALN_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (43, 240, 155, 4)
# (43, 240, 155)
# (43, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2567394919138937, 1: 87.16216216216216, 2: 12.64385987100038, 3: 69.25874610322134}
# 1/1 [==============================] - 23s 23s/step - loss: 0.3467 - dice_coef: 0.6533
# [0.34666383266448975]
# 0
# 30
# Brats18_CBICA_ALU_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (24, 240, 155, 4)
# (24, 240, 155)
# (24, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25748161751982446, 1: 96.74902470741222, 2: 12.541439568466595, 3: 38.2322713257965}
# 1/1 [==============================] - 21s 21s/step - loss: 0.3088 - dice_coef: 0.6912
# [0.30877387523651123]
# 0
# 31
# Brats18_CBICA_ALX_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (40, 240, 155, 4)
# (40, 240, 155)
# (40, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2569028838039306, 1: 35.44207317073171, 2: 14.612302616073533, 3: 92.35352532274081}
# 1/1 [==============================] - 20s 20s/step - loss: 0.4225 - dice_coef: 0.5775
# [0.4225163459777832]
# 0
# 32
# Brats18_CBICA_AME_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (42, 240, 155, 4)
# (42, 240, 155)
# (42, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2630664414505427, 1: 41.954887218045116, 2: 7.79874213836478, 3: 21.450930858366743}
# 1/1 [==============================] - 22s 22s/step - loss: 0.2514 - dice_coef: 0.7486
# [0.25140857696533203]
# 0
# 33
# Brats18_CBICA_AMH_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (33, 240, 155, 4)
# (33, 240, 155)
# (33, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.27232868981416164, 1: 35.76089489629457, 2: 3.694519014313402, 3: 34.09242390579871}
# 1/1 [==============================] - 17s 17s/step - loss: 0.2626 - dice_coef: 0.7374
# [0.26261311769485474]
# 0
# 34
# Brats18_CBICA_ANG_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (40, 240, 155, 4)
# (40, 240, 155)
# (40, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2678610003024237, 1: 14.015522568005425, 2: 6.236692541116905, 3: 28.547310260148876}
# 1/1 [==============================] - 21s 21s/step - loss: 0.4690 - dice_coef: 0.5310
# [0.46904364228248596]
# 0
# 35
# Brats18_CBICA_ANI_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (32, 240, 155, 4)
# (32, 240, 155)
# (32, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26387517002037586, 1: 39.775461106655975, 2: 6.214240968887033, 3: 41.20742176682359}
# 1/1 [==============================] - 16s 16s/step - loss: 0.2465 - dice_coef: 0.7535
# [0.2465396523475647]
# 0
# 36
# Brats18_CBICA_ANP_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (12, 240, 155, 4)
# (12, 240, 155)
# (12, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2550758027688067, 1: 327.27272727272725, 2: 15.879339783722253, 3: 73.71202113606341}
# 1/1 [==============================] - 6s 6s/step - loss: 0.3972 - dice_coef: 0.6028
# [0.3972286283969879]
# 0
# 37
# Brats18_CBICA_ANZ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (30, 240, 155, 4)
# (30, 240, 155)
# (30, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2586967063922194, 1: 26.263767297373622, 2: 16.325336454066704, 3: 28.457772337821297}
# 1/1 [==============================] - 15s 15s/step - loss: 0.3224 - dice_coef: 0.6776
# [0.3224306106567383]
# 0
# 38
# Brats18_CBICA_AOD_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2739277349180691, 1: 5.255662552556625, 2: 9.557478469981296, 3: 18.348261847452946}
# 1/1 [==============================] - 27s 27s/step - loss: 0.3497 - dice_coef: 0.6503
# [0.349702924489975]
# 0
# 39
# Brats18_CBICA_AOH_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (39, 240, 155, 4)
# (39, 240, 155)
# (39, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25562469474098176, 1: 136.04651162790697, 2: 13.81503770853965, 3: 120.77922077922078}
# 1/1 [==============================] - 20s 20s/step - loss: 0.4464 - dice_coef: 0.5536
# [0.44639772176742554]
# 0
# 40
# Brats18_CBICA_AOO_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (45, 240, 155, 4)
# (45, 240, 155)
# (45, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25972784741780247, 1: 33.706507731958766, 2: 13.051613909246843, 3: 22.97304715375748}
# 1/1 [==============================] - 24s 24s/step - loss: 0.3791 - dice_coef: 0.6209
# [0.3791229724884033]
# 0
# 41
# Brats18_CBICA_AOP_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (28, 240, 155, 4)
# (28, 240, 155)
# (28, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25895992386339567, 1: 39.5204128092275, 2: 13.886518771331058, 3: 24.340998317442512}
# 1/1 [==============================] - 16s 16s/step - loss: 0.3467 - dice_coef: 0.6533
# [0.34666937589645386]
# 0
# 42
# Brats18_CBICA_AOZ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (45, 240, 155, 4)
# (45, 240, 155)
# (45, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2643186830676883, 1: 80.49624927870744, 2: 6.650246305418719, 3: 18.554644203059187}
# 1/1 [==============================] - 24s 24s/step - loss: 0.4110 - dice_coef: 0.5890
# [0.4110460877418518]
# 0
# 43
# Brats18_CBICA_APR_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (34, 240, 155, 4)
# (34, 240, 155)
# (34, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26360324460413664, 1: 16.235366605052374, 2: 11.033183293206323, 3: 18.453457834840968}
# 1/1 [==============================] - 17s 17s/step - loss: 0.1831 - dice_coef: 0.8169
# [0.18308544158935547]
# 0
# 44
# Brats18_CBICA_APY_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (48, 240, 155, 4)
# (48, 240, 155)
# (48, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2749342381199031, 1: 39.72590549078936, 2: 3.4928757540902797, 3: 19.494301061181712}
# 1/1 [==============================] - 25s 25s/step - loss: 0.3397 - dice_coef: 0.6603
# [0.33972084522247314]
# 0
# 45
# Brats18_CBICA_APZ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (41, 240, 155, 4)
# (41, 240, 155)
# (41, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26058021982227514, 1: 44.06564197388189, 2: 10.385401062236143, 3: 23.02675282323812}
# 1/1 [==============================] - 21s 21s/step - loss: 0.3230 - dice_coef: 0.6770
# [0.32298707962036133]
# 0
# 46
# Brats18_CBICA_AQA_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (27, 240, 155, 4)
# (27, 240, 155)
# (27, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25508156819800265, 1: 43.69996519317786, 2: 44.68766684463428, 3: 29.049051365108745}
# 1/1 [==============================] - 14s 14s/step - loss: 0.5279 - dice_coef: 0.4721
# [0.5279334187507629]
# 0
# 47
# Brats18_CBICA_AQD_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (22, 240, 155, 4)
# (22, 240, 155)
# (22, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2593169040147225, 1: 120.85056113408152, 2: 9.124152693542634, 3: 38.698694912048424}
# 1/1 [==============================] - 11s 11s/step - loss: 0.3112 - dice_coef: 0.6888
# [0.31123119592666626]
# 0
# 48
# Brats18_CBICA_AQG_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (38, 240, 155, 4)
# (38, 240, 155)
# (38, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26345746548550647, 1: 202.17391304347825, 2: 5.480429253768377, 3: 59.14644351464435}
# 1/1 [==============================] - 19s 19s/step - loss: 0.4127 - dice_coef: 0.5873
# [0.41269147396087646]
# 0
# 49
# Brats18_CBICA_AQJ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (35, 240, 155, 4)
# (35, 240, 155)
# (35, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2644206750160237, 1: 50.37919826652221, 2: 7.408840533527564, 3: 15.79177178342713}
# 1/1 [==============================] - 18s 18s/step - loss: 0.2286 - dice_coef: 0.7714
# [0.22855114936828613]
# 0
# 50
# Brats18_CBICA_AQN_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (25, 240, 155, 4)
# (25, 240, 155)
# (25, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.257060313536188, 1: 29.55383246472607, 2: 28.079710144927535, 3: 24.744572158365262}
# 1/1 [==============================] - 13s 13s/step - loss: 0.4755 - dice_coef: 0.5245
# [0.4754596948623657]
# 0
# 51
# Brats18_CBICA_AQO_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (37, 240, 155, 4)
# (37, 240, 155)
# (37, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2687428831167614, 1: 41.27879078694818, 2: 4.8025792404639285, 3: 21.494159535261417}
# 1/1 [==============================] - 19s 19s/step - loss: 0.1959 - dice_coef: 0.8041
# [0.19588518142700195]
# 0
# 52
# Brats18_CBICA_AQP_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (37, 240, 155, 4)
# (37, 240, 155)
# (37, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2672374359185442, 1: 16.740452444660665, 2: 7.841841385597083, 3: 14.133738601823708}
# 1/1 [==============================] - 19s 19s/step - loss: 0.3751 - dice_coef: 0.6249
# [0.37513065338134766]
# 0
# 53
# Brats18_CBICA_AQQ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25952918614995985, 1: 20.4117466309644, 2: 19.957081545064376, 3: 20.933687480304325}
# 1/1 [==============================] - 26s 26s/step - loss: 0.3591 - dice_coef: 0.6409
# [0.35910797119140625]
# 0
# 54
# Brats18_CBICA_AQR_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (14, 240, 155, 4)
# (14, 240, 155)
# (14, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2532019742753017, 1: 222.56410256410257, 2: 53.36065573770492, 3: 36.56276326874473}
# 1/1 [==============================] - 7s 7s/step - loss: 0.3070 - dice_coef: 0.6930
# [0.3070468306541443]
# 0
# 55
# Brats18_CBICA_AQT_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (42, 240, 155, 4)
# (42, 240, 155)
# (42, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.27296875535053006, 1: 40.05332239540607, 2: 3.6615202902218846, 3: 25.97419869663519}
# 1/1 [==============================] - 22s 22s/step - loss: 0.2578 - dice_coef: 0.7422
# [0.2578084468841553]
# 0
# 56
# Brats18_CBICA_AQU_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (45, 240, 155, 4)
# (45, 240, 155)
# (45, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2652728380263701, 1: 38.12864431486881, 2: 7.074873632782784, 3: 15.942857142857143}
# 1/1 [==============================] - 23s 23s/step - loss: 0.2784 - dice_coef: 0.7216
# [0.27839839458465576]
# 0
# 57
# Brats18_CBICA_AQV_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (38, 240, 155, 4)
# (38, 240, 155)
# (38, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2583244581509261, 1: 57.07364341085271, 2: 13.316753334840605, 3: 27.559853388442644}
# 1/1 [==============================] - 20s 20s/step - loss: 0.3298 - dice_coef: 0.6702
# [0.3298071622848511]
# 0
# 58
# Brats18_CBICA_AQY_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (45, 240, 155, 4)
# (45, 240, 155)
# (45, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2684948697270591, 1: 20.727056609380416, 2: 6.237238624677706, 3: 14.934161224708275}
# 1/1 [==============================] - 23s 23s/step - loss: 0.2036 - dice_coef: 0.7964
# [0.20359259843826294]
# 0
# 59
# Brats18_CBICA_AQZ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (46, 240, 155, 4)
# (46, 240, 155)
# (46, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26466990812031777, 1: 22.317283113360112, 2: 7.012195121951219, 3: 29.16155419222904}
# 1/1 [==============================] - 24s 24s/step - loss: 0.2310 - dice_coef: 0.7690
# [0.23096828162670135]
# 0
# 60
# Brats18_CBICA_ARF_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (37, 240, 155, 4)
# (37, 240, 155)
# (37, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2633919618376354, 1: 17.303630694961278, 2: 11.404235574851688, 3: 17.271495256738444}
# 1/1 [==============================] - 19s 19s/step - loss: 0.2712 - dice_coef: 0.7288
# [0.27124208211898804]
# 0
# 61
# Brats18_CBICA_ARW_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (39, 240, 155, 4)
# (39, 240, 155)
# (39, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.25584991267102514, 1: 71.36953955135773, 2: 14.236928874234573, 3: 138.7528691660291}
# 1/1 [==============================] - 20s 20s/step - loss: 0.3981 - dice_coef: 0.6019
# [0.398078978061676]
# 0
# 62
# Brats18_CBICA_ARZ_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (14, 240, 155, 4)
# (14, 240, 155)
# (14, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2526472659956573, 1: 323.8805970149254, 2: 31.99017199017199, 3: 132.18274111675126}
# 1/1 [==============================] - 7s 7s/step - loss: 0.5477 - dice_coef: 0.4523
# [0.5476522445678711]
# 0
# 63
# Brats18_CBICA_ASA_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (45, 240, 155, 4)
# (45, 240, 155)
# (45, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2646141628328701, 1: 25.274791641502595, 2: 11.52384623857253, 3: 10.574056293900652}
# 1/1 [==============================] - 23s 23s/step - loss: 0.2378 - dice_coef: 0.7622
# [0.2378109246492386]
# 0
# 64
# Brats18_CBICA_ASE_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (16, 240, 155, 4)
# (16, 240, 155)
# (16, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2590957766343668, 1: 912.8834355828221, 2: 7.620218159471501, 3: 123.48547717842324}
# 1/1 [==============================] - 8s 8s/step - loss: 0.4531 - dice_coef: 0.5469
# [0.4531322717666626]
# 0
# 65
# Brats18_CBICA_ASG_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2634380305939366, 1: 17.471350742062747, 2: 10.506337694028334, 3: 19.37096438242033}
# 1/1 [==============================] - 26s 26s/step - loss: 0.3606 - dice_coef: 0.6394
# [0.36057227849960327]
# 0
# 66
# Brats18_CBICA_ASH_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (17, 240, 155, 4)
# (17, 240, 155)
# (17, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.256596693619328, 1: 112.04819277108433, 2: 12.293934681181959, 3: 79.56718671363865}
# 1/1 [==============================] - 9s 9s/step - loss: 0.3451 - dice_coef: 0.6549
# [0.3451237082481384]
# 0
# 67
# Brats18_CBICA_ASK_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (23, 240, 155, 4)
# (23, 240, 155)
# (23, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2680787066048377, 1: 134.6977329974811, 2: 4.258496087917338, 3: 36.359000509943904}
# 1/1 [==============================] - 12s 12s/step - loss: 0.3477 - dice_coef: 0.6523
# [0.347662091255188]
# 0
# 68
# Brats18_CBICA_ASN_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (50, 240, 155, 4)
# (50, 240, 155)
# (50, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26154760813306194, 1: 13.054463784390792, 2: 31.978543428925107, 3: 14.549436795994994}
# 1/1 [==============================] - 26s 26s/step - loss: 0.4172 - dice_coef: 0.5828
# [0.41722574830055237]
# 0
# 69
# Brats18_CBICA_ASO_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (29, 240, 155, 4)
# (29, 240, 155)
# (29, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2697121370461671, 1: 60.62036412677006, 2: 4.389291236064773, 3: 20.824646745425063}
# 1/1 [==============================] - 15s 15s/step - loss: 0.2781 - dice_coef: 0.7219
# [0.2781451344490051]
# 0
# 70
# Brats18_CBICA_ASU_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (29, 240, 155, 4)
# (29, 240, 155)
# (29, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26039881473642945, 1: 45.03255969277008, 2: 10.239179954441914, 3: 25.083705357142858}
# 1/1 [==============================] - 15s 15s/step - loss: 0.1801 - dice_coef: 0.8199
# [0.18013465404510498]
# 0
# 71
# Brats18_CBICA_ASV_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (38, 240, 155, 4)
# (38, 240, 155)
# (38, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.27084361578526256, 1: 28.511496571198062, 2: 4.047275475846904, 3: 38.94214876033058}
# 1/1 [==============================] - 20s 20s/step - loss: 0.3709 - dice_coef: 0.6291
# [0.37086302042007446]
# 0
# 72
# Brats18_CBICA_ASW_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (35, 240, 155, 4)
# (35, 240, 155)
# (35, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.2646360827030442, 1: 48.94000902119982, 2: 9.267959340565474, 3: 10.764956840956444}
# 1/1 [==============================] - 19s 19s/step - loss: 0.2292 - dice_coef: 0.7708
# [0.22917185723781586]
# 0
# 73
# Brats18_CBICA_ASY_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (38, 240, 155, 4)
# (38, 240, 155)
# (38, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.267199755633953, 1: 53.70004558577724, 2: 4.658151765589782, 3: 41.35267961619471}
# 1/1 [==============================] - 20s 20s/step - loss: 0.2052 - dice_coef: 0.7948
# [0.20518004894256592]
# 0
# 74
# Brats18_CBICA_ATB_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (34, 240, 155, 4)
# (34, 240, 155)
# (34, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26056538238093474, 1: 35.825968728755946, 2: 17.969993180268244, 3: 12.717692957406587}
# 1/1 [==============================] - 18s 18s/step - loss: 0.3187 - dice_coef: 0.6813
# [0.3187035322189331]
# 0
# 75
# Brats18_CBICA_ATD_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (24, 240, 155, 4)
# (24, 240, 155)
# (24, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26782371631804786, 1: 70.87964433153383, 2: 4.65649969749442, 3: 26.781857451403887}
# 1/1 [==============================] - 14s 14s/step - loss: 0.3454 - dice_coef: 0.6546
# [0.3454321622848511]
# 0
# 76
# Brats18_CBICA_ATF_1
# Entered modality
# Entered ground truth
# Entered modality
# Entered modality
# Entered modality
# (240, 240, 155, 4)
# (240, 240, 155)
# (34, 240, 155, 4)
# (34, 240, 155)
# (34, 240, 155)
# Number of classes [0 1 2 3]
# class_weights {0: 0.26553198350376256, 1: 30.16599885518031, 2: 5.431776407331696, 3: 59.79576399394856}
